# %% [markdown]
# # Instructions

# %% [markdown]
# Please do the following Steps Before starting the Project
# 1. Watch this video: https://youtu.be/5PDMp1HywL4
# 2. Goto the file -> Save a copy in Drive
# 3. Open the Copied Colab file and close the original Colab file
# 4. Change the name in top left corner of the file to your **Team No. and 3 Roll No.**
# 5. Change the share setting to anyone can **edit**
# 6. Please Refer to your class notes
# https://tinyurl.com/ARJPYTHON
# 7. If you have any doubts please ask your mentors, or you can directly mail us your doubts arjuna.jntu.python@gmail.com

# %% [markdown]
# # Some definition
#
# **Factors:** A factor is a number that divides another number, leaving no remainder. In other words, if multiplying two whole numbers gives us a product, then the numbers we are multiplying are factors of the product because they are divisible by the product. Factors are also divisors
#
# **Prime:**A prime number is a number that is only divisible by 1 and itself. So, prime numbers have only two factors, 1 and the number itself
#
# **Prime Factors:** Factors which are prime

# %% [markdown]
# # Functions

# %%
# Enter as many functions as you like

# %%
def prime_numbers(n):
    primes = []
    for num in range(2, n + 1):
        for i in range(2, num):
            if (num % i) == 0:
                break
        else:
          primes.append(num)
    return primes

# %% [markdown]
# #a)
# Get the User's number by printing "Enter any number:"
#
# Generate a code to get all the prime factors of any number given by the User
#
# Print the prime factors as shown below
#
#
# ---
#
#
# **Sample Output 1**
#
# Enter any number:**60**
#
# Prime factors of 60 are [2, 3, 5]
#
#
#
# ---
# **Sample Output 2**
#
# Enter any number:**64**
#
# Prime factors of 64 is [2]
#
#
# ---
#
# **Bold font means Given by the User**
#
# Note if there is only 1 prime factor then you have to use "is", otherwise you have to use "are"

# %%
arr=[]
n = int(input("Enter a number: "))
for k in prime_numbers(n):
   if (n%k==0):
     arr.append(k)
s=len(arr)
if (s>1):
 print("Prime factors of ",n," are ",arr)
if (s==1):
 print("Prime factors of ",n," is ",arr)
# Out:
# Enter a number: 131
# Prime factors of  131  is  [131]

# %% [markdown]
# # b)
#
# Print the maximum power of the primes above are factors of number given by the user
#
#
# ---
#
#
#
# **Sample Output 1**
#
# Enter any number:**120**
#
# Prime factors of 120 are [2, 3, 5]
#
# The maximum power of 2 which is factor of 120 is 3
#
# The maximum power of 3 which is factor of 120 is 1
#
# The maximum power of 5 which is factor of 120 is 1

# %%
arr=[]
count=1
n = int(input("Enter a number: "))
for k in prime_numbers(n):
   if (n%k==0):
     arr.append(k)
s=len(arr)
if (s>1):
 print("Prime factors of ",n," are ",arr)
if (s==1):
 print("Prime factors of ",n," is ",arr)

for q in arr:
  p=n/q
  count=1
  while p>0:
    if (p%q==0):
      count=count+1
    p=p/q
  print("the maximum power of",q,"which is factor of ",n,"is", count)
# Out:
# Enter a number: 121
# Prime factors of  121  is  [11]
# the maximum power of 11 which is factor of  121 is 2

# %% [markdown]
# # c)

# %% [markdown]
# Write the code in prime power format as shown below
#
#
# ---
#
#
# **Sample Output 1**
#
# Enter any number:**120**
#
# Prime factors of 120 are [2, 3, 5]
#
# The maximum power of 2 which is factor of 120 is 3
#
# The maximum power of 3 which is factor of 120 is 1
#
# The maximum power of 5 which is factor of 120 is 1
#
# Prime power of 120 is 2^3 * 3^1 * 5^1

# %%
arr=[]
brr=[]
count=1
w=0
n = int(input("Enter a number: "))
for k in prime_numbers(n):
   if (n%k==0):
     arr.append(k)

s=len(arr)
if (s>1):
 print("Prime factors of ",n," are ",arr)
if (s==1):
 print("Prime factors of ",n," is ",arr)

for q in arr:
  p=n/q
  count=1
  while p>0:
    if (p%q==0):
      count=count+1
    p=p/q
  print("the maximum power of",q,"which is factor of ",n,"is", count)
  brr.append(count)
e=len(arr)
print("Prime power of", n ,"is ", end="")
while w<e :
  if (w==e-1):
    print(arr[w],"^",brr[w])
    break
  if (w<e-1):
    print(arr[w],"^",brr[w],"*",end="")
    w=w+1
# Out:
# Enter a number: 27720
# Prime factors of  27720  are  [2, 3, 5, 7, 11]
# the maximum power of 2 which is factor of  27720 is 3
# the maximum power of 3 which is factor of  27720 is 2
# the maximum power of 5 which is factor of  27720 is 1
# the maximum power of 7 which is factor of  27720 is 1
# the maximum power of 11 which is factor of  27720 is 1
# Prime power of 27720 is 2 ^ 3 *3 ^ 2 *5 ^ 1 *7 ^ 1 *11 ^ 1

# %% [markdown]
# # d)

# %% [markdown]
# Ask User the size of array by printing("What is the size of array? ")
#
# Then accordingly ask array elements by printing("Enter element:")
#
# Then print the prime power of each element

# %% [markdown]
# **Sample Output**
#
# What is the size of array? **4**
#
# Enter element:**20**
#
# Enter element:**7**
#
# Enter element:**1034**
#
# Enter element:**1024**
#
# Prime power of 20 is 2^2 * 5^1
#
# Prime power of 7 is 7^1
#
# Prime power of 1034 is 2^1 * 11^1 * 47^1
#
# Prime power of 1024 is 2^10

# %%
crr = []
t = int(input("No. of elements:"))
for y in range(t):
 el = int(input("Enter element:"))
 crr.append(el)
for n in crr:
 arr=[]
 brr=[]
 count=1
 w=0
 for k in prime_numbers(n):
    if (n%k==0):
      arr.append(k)
 for q in arr:
   p=n/q
   count=1
   while p>0:
     if (p%q==0):
       count=count+1
     p=p/q
   brr.append(count)
 e=len(arr)
 print("Prime power of", n ,"is ", end="")
 while w<e :
   if (w==e-1):
     print(arr[w],"^",brr[w])
     break
   if (w<e-1):
     print(arr[w],"^",brr[w],"*",end="")
     w=w+1
# Out:
# No. of elements:3
# Enter element:34
# Enter element:40
# Enter element:48
# Prime power of 34 is 2 ^ 1 *17 ^ 1
# Prime power of 40 is 2 ^ 3 *5 ^ 1
# Prime power of 48 is 2 ^ 4 *3 ^ 1

# %% [markdown]
# # e)

# %% [markdown]
# Create a program that will generate the correct suffix(st,th,rd,nd) for number given by the User.
#
# Ask User for the number printing "Enter number:" and accept the number and print the suffix
#
#
# ---
#
# **Sample Output 1**
#
# Enter number:**3**
#
# The suffix is rd
#
#
# ---
#
#
#
# **Sample Output 2**
#
# Enter number:**11**
#
# The suffix is th
#
#
# ---
#
#
#
# **Sample Output 3**
#
# Enter number:**112**
#
# The suffix is th
#
#
# ---
#
#
#
# **Sample Output 4**
#
# Enter number:**22**
#
# The suffix is nd

# %%
t=0
suf = ["st","nd","rd","th"]
a=int(input("Enter any number:"))

if(a>0 and a<10):
  if(a==0):
   print("The suffix is" , suf[3])
  if(a==1):
   print("The suffix is" , suf[0])
  if(a==2):
   print("The suffix is" , suf[1])
  if(a==3):
   print("The suffix is" , suf[2])
  if(a>3 and a<=9):
   print("The suffix is" , suf[3])
elif(a%100==11):
 print("The suffix is" , suf[3])

elif(a%100==12):
 print("The suffix is" , suf[3])

elif(a%100==13):
 print("The suffix is" , suf[3])

elif(a>10 and a<20):
  print("The suffix is" , suf[3])

elif(a>=20):
  if(a%10==0):
   print("The suffix is" , suf[3])

  if(a%10==1):
   print("The suffix is" , suf[0])

  if(a%10==2):
   print("The suffix is" , suf[1])

  if(a%10==3):
   print("The suffix is" , suf[2])
  if(a%10>3 and a%10<=9):
   print("The suffix is" , suf[3])
# Out:
# Enter any number:223
# The suffix is rd

# %% [markdown]
# # f)

# %% [markdown]
# Incorporate the correct suffix of each number as shown in the below output
#
#
# ---
#
# **Sample Output**
#
# What is the size of array? **4**
#
# Enter element:**1024**
#
# Enter element:**1001**
#
# Enter element:**7**
#
# Enter element:**2520**
#
# Prime power of 1st number 1024 is 2^10
#
# Prime power of 2nd number 1001 is 7^1 * 11^1 * 13^1
#
# Prime power of 3rd number 7 is 7^1
#
# Prime power of 4th number 2520 is 2^3 * 3^2 * 5^1 * 7^1

# %%
crr = []
t = int(input("No. of elements:"))
a=0
for y in range(t):
 ele = int(input("Enter element:"))
 crr.append(ele)
for n in crr:
 arr=[]
 brr=[]
 count=1
 w=0

 a=a+1
 for k in prime_numbers(n):

    if (n%k==0):
      arr.append(k)
 for q in arr:
   p=n/q
   count=1
   while p>0:
     if (p%q==0):
       count=count+1
     p=p/q
   brr.append(count)
 e=len(arr)
 suf = ["st","nd","rd","th"]
 if(a>10 and a<20):
   print("Prime power of", a, suf[3],"number", n ,"is ",end="")

 elif(a>=20):
   if(a%10==0):
    print("Prime power of", a, suf[3],"number", n,"is ",end="")


   elif(a%10==1):
    print("Prime power of", a, suf[0],"number", n,"is ",end="")


   elif(a%10==2):
    print("Prime power of", a, suf[1],"number", n,"is ",end="")


   elif(a%10==3):
    print("Prime power of", a, suf[2],"number", n,"is ",end="")

   elif(a%10>3 and a%10<=9):
    print("Prime power of", a, suf[3],"number", n,"is ",end="")

 elif(a%100==11):
  print("Prime power of", a, suf[3],"number", n ,"is ",end="")

 elif(a%100==12):
  print("Prime power of", a, suf[3],"number", n ,"is ",end="")

 elif(a%100==13):
  print("Prime power of", a, suf[3],"number", n ,"is ",end="")

 elif(a>10 and a<20):
  print("Prime power of", a, suf[3],"number", n ,"is ",end="")

 elif(a>0 and a<10):
   if(a==0):
    print("Prime power of", a, suf[3],"number", n,"is ",end="")

   elif(a==1):
    print("Prime power of", a, suf[0],"number", n,"is ",end="")

   elif(a==2):
    print("Prime power of", a, suf[1],"number", n,"is ",end="")

   elif(a==3):
    print("Prime power of", a, suf[2],"number", n,"is ",end="")
   elif(a>3 and a<=9):
    print("Prime power of", a,suf[3],"number", n,"is ",end="")
 while w<e :
   if (w==e-1):
     print(arr[w],"^",brr[w])
     break
   if (w<e-1):
     print(arr[w],"^",brr[w],"*",end="")
     w=w+1
# Out:
# No. of elements:4
# Enter element:1024
# Enter element:1001
# Enter element:7
# Enter element:2520
# Prime power of 1 st number 1024 is 2 ^ 10
# Prime power of 2 nd number 1001 is 7 ^ 1 *11 ^ 1 *13 ^ 1
# Prime power of 3 rd number 7 is 7 ^ 1
# Prime power of 4 th number 2520 is 2 ^ 3 *3 ^ 2 *5 ^ 1 *7 ^ 1

# %% [markdown]
# Submission Form Link: https://tinyurl.com/ARJProjForm
#
# Deadline: **19th Feb 10 PM**
